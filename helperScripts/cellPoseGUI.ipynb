# %%
# !python -m cellpose --gpu_device mps --use_gpu
# Out:
# 2024-04-18 22:20:11,438 [INFO] WRITING LOG OUTPUT TO /Users/mzo5929/.cellpose/run.log
# 2024-04-18 22:20:11,439 [INFO]
# cellpose version: 	3.0.7
# platform:       	darwin
# python version: 	3.11.8
# torch version:  	2.2.2
# 2024-04-18 22:20:11,621 [INFO] TORCH CUDA version not installed/working.
# GUI_INFO: loading image: /Volumes/fsmresfiles/Basic_Sciences/CDB/GoyalLab/People/KeerthanaArun/ArispeLab/MoisesEtAl/extractedData/segmentationResults/figure6/2024_03_08_acetyltub_kocells/TrainingData/huvec_sm9_hdac6ko_flow_vecad__0012_zoverlay.jpg
# GUI_INFO: normalization checked: computing saturation levels (and optionally filtered image)
# {'lowhigh': None, 'percentile': [1.0, 99.0], 'normalize': True, 'norm3D': False, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# [0.0, 254.0]
# GUI_INFO: selected model Figure6New-2, loading now
# 2024-04-18 22:20:49,782 [INFO] >> Figure6New-2 << model set to be used
# ...

# %%
# %pip install cellpose[gui]
