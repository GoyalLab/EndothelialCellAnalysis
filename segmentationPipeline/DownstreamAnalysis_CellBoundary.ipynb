# %% [markdown]
# # Downstream Analysis of cell segmentation
# This code takes the numpy.files generated by cellpose and tabulates physical properties for each mask(major axis and minor axis length, area of mask , centroid, orientation, mean intensity in each channel). The values are saved in a csv file.

# %%
import numpy as np
import pandas as pd
from skimage.measure import regionprops_table
import skimage.measure
import math
import matplotlib.pyplot as plt
import os
from os import listdir
from cellpose import plot, utils
import cellpose
import skimage.io
from scipy import stats

# %%
import os

# Root directory that contains output files
dirPath = '/home/mzo5929/Keerthana/MoiseEtAl/extractedData/segmentationResults/figure6/'
inputPath1 = []

# Walk through all directories and files in dirPath
for root, dirs, files in os.walk(dirPath):
    # Filter for .npy files
    for file in files:
        if file.endswith(".npy"):
            filePath = os.path.join(root, file)
            inputPath1.append(filePath)

# inputPath1 now contains paths to all .npy files under dirPath, including in deeply nested subdirectories

# %%
len(inputPath1)

# %% [markdown]
# Only for K40A static (to only consider images without the string spec)

# %%
spec = "flow"
inputPath1= [i for i in inputPath1 if not spec in i]

# %% [markdown]
# For specific input files (enter below)

# %%
inputPath1 = ['']

# %% [markdown]
# Regular- elongation/eccentricity (for most images)

# %%
properties = ('label','centroid', 'area', 'orientation', 'major_axis_length', 'minor_axis_length', 'bbox')
index = 0
for inputPath in inputPath1:
    print(index)
    index = index + 1
    data = np.load(inputPath, allow_pickle=True).item()
    outlines = data['outlines']
    masks = data['masks']
    image = data['img']
    uniqueCells = np.unique(masks)
    #Remove boundary conditions 
    excludeX = np.arange(image.shape[1] - 4 ,image.shape[1] +1)
    downValues = np.arange(0,5)
    excludeX = np.concatenate((downValues, excludeX))
    excludeY = np.arange(image.shape[0] - 4 ,image.shape[0] +1)
    excludeY = np.concatenate((downValues, excludeY))
    for c in uniqueCells:
        if c != 0:
            cellCoord = np.where(masks==c)
            checkY = np.isin(cellCoord[0],excludeY)
            checkX = np.isin(cellCoord[1],excludeX)
            if np.any(checkY):
              masks[cellCoord[0], cellCoord[1]] = 0
              outlines[cellCoord[0], cellCoord[1]] = 0
            elif np.any(checkX):
              masks[cellCoord[0], cellCoord[1]] = 0
              outlines[cellCoord[0], cellCoord[1]] = 0
    masks_array = np.asarray(masks)
    prop_dict = regionprops_table(masks_array, properties = properties)
    df = pd.DataFrame(prop_dict)
    def coordinates(row, coord):
        if coord == "xMajor1":
            return row ['centroid-1'] - math.sin(row['orientation']) * 0.5 * row['major_axis_length']
        elif coord == "yMajor1":
            return row ['centroid-0'] - math.cos(row['orientation']) * 0.5 * row['major_axis_length']
        elif coord == "xMinor1":
            return row ['centroid-1'] + math.cos(row['orientation']) * 0.5 * row['minor_axis_length']
        elif coord == "yMinor1":
            return row ['centroid-0'] - math.sin(row['orientation']) * 0.5 * row['minor_axis_length']


        elif coord == "xMajor2":
            return row ['centroid-1'] + math.sin(row['orientation']) * 0.5 * row['major_axis_length']
        elif coord == "yMajor2":
            return row ['centroid-0'] + math.cos(row['orientation']) * 0.5 * row['major_axis_length']
        elif coord == "xMinor2":
            return row ['centroid-1'] - math.cos(row['orientation']) * 0.5 * row['minor_axis_length']
        elif coord == "yMinor2":
            return row ['centroid-0'] + math.sin(row['orientation']) * 0.5 * row['minor_axis_length']
        else:
            return 0

    #Plot major and minor axis
    df['xMajor1'] = df.apply(lambda row: coordinates(row, "xMajor1"), axis=1)
    df['yMajor1'] = df.apply(lambda row: coordinates(row, "yMajor1"), axis=1)
    df['xMinor1'] = df.apply(lambda row: coordinates(row, "xMinor1"), axis=1)
    df['yMinor1'] = df.apply(lambda row: coordinates(row, "yMinor1"), axis=1)

    df['xMajor2'] = df.apply(lambda row: coordinates(row, "xMajor2"), axis=1)
    df['yMajor2'] = df.apply(lambda row: coordinates(row, "yMajor2"), axis=1)
    df['xMinor2'] = df.apply(lambda row: coordinates(row, "xMinor2"), axis=1)
    df['yMinor2'] = df.apply(lambda row: coordinates(row, "yMinor2"), axis=1)

    x0 = df['centroid-1']
    y0 = df['centroid-0']
    xMajor1 = df['xMajor1']
    xMajor2 = df['xMajor2']
    yMajor1 = df['yMajor1']
    yMajor2 = df['yMajor2']

    xMinor1 = df['xMinor1']
    xMinor2 = df['xMinor2']
    yMinor1 = df['yMinor1']
    yMinor2 = df['yMinor2']

    fig, ax = plt.subplots(figsize=(10, 6))
    ax.imshow(image, cmap=plt.cm.gray)

    #ax.plot((x0, xMajor1), (y0, yMajor1), '-r', linewidth=1)
    #ax.plot((x0, xMinor1), (y0, yMinor1), '-r', linewidth=1)

    ax.plot((xMajor1, xMajor2), (yMajor1, yMajor2), '-r', linewidth=1)
    ax.plot((xMinor1, xMinor2), (yMinor1, yMinor2), '-g', linewidth=1)
    ax.plot(x0, y0, '.g', markersize=2)
    outputBasePath = inputPath.replace("segmentationResults", "parameterResults")
    outputBasePath = outputBasePath.replace('/Segmentation', '')
    # Derive the base directory for 'parameterResults' and append the specific subfolders 'image' and 'csv'
    outputImageDir = os.path.join(os.path.dirname(outputBasePath), "Images")
    outputCsvDir = os.path.join(os.path.dirname(outputBasePath), "Parameters")

    # Ensure the output directories exist
    os.makedirs(outputImageDir, exist_ok=True)
    os.makedirs(outputCsvDir, exist_ok=True)

    # Define the output file names, replacing '.npy' with the appropriate extension
    outputImageFile = os.path.basename(outputBasePath).replace(".npy", ".png")
    outputCsvFile = os.path.basename(outputBasePath).replace(".npy", ".csv")
    print(outputImageFile)
    # Construct the full paths for the output files
    outputImagePath = os.path.join(outputImageDir, outputImageFile)
    outputCsvPath = os.path.join(outputCsvDir, outputCsvFile)

    # Save the plot as a PNG image in the 'image' subfolder
    plt.savefig(outputImagePath, dpi = 300)
    # plt.show()

    # Save the DataFrame as a CSV file in the 'csv' subfolder
    # Assuming 'df' is your DataFrame
    df.to_csv(outputCsvPath)

###Till here
# Out:
# 0
# huvec_sm9_hdac6ko_flow_vecad__0031_zoverlay_seg.png
# 1
# huvec_sm9_hdac6ko_flow_vecad__0029_zoverlay_seg.png
# 2
# huvec_sm9_hdac6ko_flow_vecad__0009_zoverlay_seg.png
# 3
# huvec_sm9_hdac6ko_flow_vecad__0041_zoverlay_seg.png
# 4
# huvec_sm9_hdac6ko_flow_vecad__0008_zoverlay_seg.png
# 5
# huvec_sm9_hdac6ko_flow_vecad__0001_zoverlay_seg.png
# 6
# huvec_sm9_hdac6ko_flow_vecad__0015_zoverlay_seg.png
# 7
# huvec_sm9_hdac6ko_flow_vecad__0036_zoverlay_seg.png
# 8
# huvec_sm9_hdac6ko_flow_vecad__0038_zoverlay_seg.png
# 9
# huvec_sm9_hdac6ko_flow_vecad__0043_zoverlay_seg.png
# 10
# huvec_sm9_hdac6ko_flow_vecad__0039_zoverlay_seg.png
# 11
# huvec_sm9_hdac6ko_flow_vecad__0045_zoverlay_seg.png
# 12
# huvec_sm9_hdac6ko_flow_vecad__0023_zoverlay_seg.png
# 13
# huvec_sm9_hdac6ko_flow_vecad__0007_zoverlay_seg.png
# 14
# huvec_sm9_hdac6ko_flow_vecad__0035_zoverlay_seg.png
# 15
# huvec_sm9_hdac6ko_flow_vecad__0000_zoverlay_seg.png
# 16
# huvec_sm9_hdac6ko_flow_vecad__0030_zoverlay_seg.png
# 17
# huvec_sm9_hdac6ko_flow_vecad__0010_zoverlay_seg.png
# 18
# huvec_sm9_hdac6ko_flow_vecad__0013_zoverlay_seg.png
# 19
# huvec_sm9_hdac6ko_flow_vecad__0019_zoverlay_seg.png
# 20
# /tmp/ipykernel_261660/49758790.py:76: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(10, 6))
# huvec_sm9_hdac6ko_flow_vecad__0026_zoverlay_seg.png
# 21
# huvec_sm9_hdac6ko_flow_vecad__0021_zoverlay_seg.png
# 22
# huvec_sm9_hdac6ko_flow_vecad__0020_zoverlay_seg.png
# 23
# huvec_sm9_hdac6ko_flow_vecad__0012_zoverlay_seg.png
# 24
# huvec_sm9_hdac6ko_flow_vecad__0040_zoverlay_seg.png
# 25
# huvec_sm9_hdac6ko_flow_vecad__0022_zoverlay_seg.png
# 26
# huvec_sm9_hdac6ko_flow_vecad__0033_zoverlay_seg.png
# 27
# huvec_sm9_hdac6ko_flow_vecad__0006_zoverlay_seg.png
# 28
# huvec_sm9_hdac6ko_flow_vecad__0011_zoverlay_seg.png
# 29
# huvec_sm9_hdac6ko_flow_vecad__0016_zoverlay_seg.png
# 30
# huvec_sm9_hdac6ko_flow_vecad__0014_zoverlay_seg.png
# 31
# huvec_sm9_hdac6ko_flow_vecad__0018_zoverlay_seg.png
# 32
# huvec_sm9_hdac6ko_flow_vecad__0025_zoverlay_seg.png
# 33
# huvec_sm9_hdac6ko_flow_vecad__0034_zoverlay_seg.png
# 34
# huvec_sm9_hdac6ko_flow_vecad__0042_zoverlay_seg.png
# 35
# huvec_sm9_hdac6ko_flow_vecad__0003_zoverlay_seg.png
# 36
# huvec_sm9_hdac6ko_flow_vecad__0024_zoverlay_seg.png
# 37
# huvec_sm9_hdac6ko_flow_vecad__0027_zoverlay_seg.png
# 38
# huvec_sm9_hdac6ko_flow_vecad__0005_zoverlay_seg.png
# 39
# huvec_sm9_hdac6ko_flow_vecad__0044_zoverlay_seg.png
# 40
# huvec_sm9_hdac6ko_flow_vecad__0002_zoverlay_seg.png
# 41
# huvec_sm9_hdac6ko_flow_vecad__0028_zoverlay_seg.png
# 42
# huvec_sm9_hdac6ko_flow_vecad__0037_zoverlay_seg.png
# 43
# huvec_sm9_hdac6ko_flow_vecad__0046_zoverlay_seg.png
# 44
# huvec_sm9_hdac6ko_flow_vecad__0004_zoverlay_seg.png
# 45
# huvec_sm9_hdac6ko_flow_vecad__0017_zoverlay_seg.png
# 46
# huvec_sm9_hdac6ko_flow_vecad__0032_zoverlay_seg.png
# 47
# huvec_sm9_veh_static_vecad__0001_zoverlay_seg.png
# 48
# huvec_sm9_veh_static_vecad__0003_zoverlay_seg.png
# 49
# huvec_sm9_veh_static_vecad__0002_zoverlay_seg.png
# 50
# huvec_sm9_veh_static_vecad__0006_zoverlay_seg.png
# 51
# huvec_sm9_veh_static_vecad__0000_zoverlay_seg.png
# 52
# huvec_sm9_veh_static_vecad__0009_zoverlay_seg.png
# 53
# huvec_sm9_veh_static_vecad__0007_zoverlay_seg.png
# 54
# huvec_sm9_veh_static_vecad__0005_zoverlay_seg.png
# 55
# huvec_sm9_veh_static_vecad__0011_zoverlay_seg.png
# 56
# huvec_sm9_veh_static_vecad__0004_zoverlay_seg.png
# 57
# huvec_sm9_veh_static_vecad__0010_zoverlay_seg.png
# 58
# huvec_sm9_veh_static_vecad__0008_zoverlay_seg.png
# 59
# huvec_sm9_hdac6ko_static_vecad__0011_zoverlay_seg.png
# 60
# huvec_sm9_hdac6ko_static_vecad__0005_zoverlay_seg.png
# 61
# huvec_sm9_hdac6ko_static_vecad__0009_zoverlay_seg.png
# 62
# huvec_sm9_hdac6ko_static_vecad__0014_zoverlay_seg.png
# 63
# huvec_sm9_hdac6ko_static_vecad__0007_zoverlay_seg.png
# 64
# huvec_sm9_hdac6ko_static_vecad__0006_zoverlay_seg.png
# 65
# huvec_sm9_hdac6ko_static_vecad__0004_zoverlay_seg.png
# 66
# huvec_sm9_hdac6ko_static_vecad__0012_zoverlay_seg.png
# 67
# huvec_sm9_hdac6ko_static_vecad__0008_zoverlay_seg.png
# 68
# huvec_sm9_hdac6ko_static_vecad__0015_zoverlay_seg.png
# 69
# huvec_sm9_hdac6ko_static_vecad__0002_zoverlay_seg.png
# 70
# huvec_sm9_hdac6ko_static_vecad__0001_zoverlay_seg.png
# 71
# huvec_sm9_hdac6ko_static_vecad__0003_zoverlay_seg.png
# 72
# huvec_sm9_hdac6ko_static_vecad__0013_zoverlay_seg.png
# 73
# huvec_sm9_hdac6ko_static_vecad__0000_zoverlay_seg.png
# 74
# huvec_sm9_hdac6ko_static_vecad__0010_zoverlay_seg.png
# 75
# huvec_sm9_atat1ko_flow_vecad__0001_zoverlay_seg.png
# 76
# huvec_sm9_atat1ko_flow_vecad__0020_zoverlay_seg.png
# 77
# huvec_sm9_atat1ko_flow_vecad__0006_zoverlay_seg.png
# 78
# huvec_sm9_atat1ko_flow_vecad__0005_zoverlay_seg.png
# 79
# huvec_sm9_atat1ko_flow_vecad__0008_zoverlay_seg.png
# 80
# huvec_sm9_atat1ko_flow_vecad__0014_zoverlay_seg.png
# 81
# huvec_sm9_atat1ko_flow_vecad__0012_zoverlay_seg.png
# 82
# huvec_sm9_atat1ko_flow_vecad__0013_zoverlay_seg.png
# 83
# huvec_sm9_atat1ko_flow_vecad__0015_zoverlay_seg.png
# 84
# huvec_sm9_atat1ko_flow_vecad__0011_zoverlay_seg.png
# 85
# huvec_sm9_atat1ko_flow_vecad__0004_zoverlay_seg.png
# 86
# huvec_sm9_atat1ko_flow_vecad__0019_zoverlay_seg.png
# 87
# huvec_sm9_atat1ko_flow_vecad__0018_zoverlay_seg.png
# 88
# huvec_sm9_atat1ko_flow_vecad__0003_zoverlay_seg.png
# 89
# huvec_sm9_atat1ko_flow_vecad__0010_zoverlay_seg.png
# 90
# huvec_sm9_atat1ko_flow_vecad__0007_zoverlay_seg.png
# 91
# huvec_sm9_atat1ko_flow_vecad__0016_zoverlay_seg.png
# 92
# huvec_sm9_atat1ko_flow_vecad__0000_zoverlay_seg.png
# 93
# huvec_sm9_atat1ko_flow_vecad__0009_zoverlay_seg.png
# 94
# huvec_sm9_atat1ko_flow_vecad__0002_zoverlay_seg.png
# 95
# huvec_sm9_atat1ko_flow_vecad__0021_zoverlay_seg.png
# 96
# huvec_sm9_veh_flow_vecad__0000_zoverlay_seg.png
# 97
# huvec_sm9_veh_flow_vecad__0007_zoverlay_seg.png
# 98
# huvec_sm9_veh_flow_vecad__0005_zoverlay_seg.png
# 99
# huvec_sm9_veh_flow_vecad__0004_zoverlay_seg.png
# 100
# huvec_sm9_veh_flow_vecad__0001_zoverlay_seg.png
# 101
# huvec_sm9_veh_flow_vecad__0003_zoverlay_seg.png
# 102
# huvec_sm9_veh_flow_vecad__0002_zoverlay_seg.png
# 103
# huvec_sm9_veh_flow_vecad__0008_zoverlay_seg.png
# 104
# huvec_sm9_veh_flow_vecad__0006_zoverlay_seg.png
# 105
# huvec_sm9_atat1ko_static_vecad__0007_zoverlay_seg.png
# 106
# huvec_sm9_atat1ko_static_vecad__0010_zoverlay_seg.png
# 107
# huvec_sm9_atat1ko_static_vecad__0003_zoverlay_seg.png
# 108
# huvec_sm9_atat1ko_static_vecad__0004_zoverlay_seg.png
# 109
# huvec_sm9_atat1ko_static_vecad__0000_zoverlay_seg.png
# 110
# huvec_sm9_atat1ko_static_vecad__0009_zoverlay_seg.png
# 111
# huvec_sm9_atat1ko_static_vecad__0001_zoverlay_seg.png
# 112
# huvec_sm9_atat1ko_static_vecad__0011_zoverlay_seg.png
# 113
# huvec_sm9_atat1ko_static_vecad__0002_zoverlay_seg.png
# 114
# huvec_sm9_atat1ko_static_vecad__0006_zoverlay_seg.png
# 115
# huvec_sm9_atat1ko_static_vecad__0008_zoverlay_seg.png
# 116
# huvec_sm9_atat1ko_static_vecad__0005_zoverlay_seg.png

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread

def list_images(directory):
    """ Recursively list all image files under the given directory grouped by subdirectory """
    image_files = {}
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                if root not in image_files:
                    image_files[root] = []
                image_files[root].append(os.path.join(root, file))
    return image_files

def display_images_by_folder(image_dict, figsize=(20, 12), dpi=300):
    """ Display images grouped by their folder, with each image displayed using specified figsize and dpi """
    for folder, images in image_dict.items():
        for image in images:
            fig, ax = plt.subplots(figsize=figsize)
            fig.suptitle(f'Image from {folder}: {os.path.basename(image)}')
            img = imread(image)
            ax.imshow(img)
            ax.axis('off')
            plt.show()

# Usage example:
root_directory = '/home/mzo5929/Keerthana/MoiseEtAl/extractedData/parameterResults/figure3/'  # Update this to your images directory path
images = list_images(root_directory)
display_images_by_folder(images)

# %% [markdown]
# For K40 mutants - only fitc channel

# %%
properties = ('label', 'mean_intensity', 'major_axis_length', 'minor_axis_length','orientation')
for inputPath in inputPath1:
    data = np.load(inputPath, allow_pickle=True).item()
    outlines = data['outlines']
    masks = data['masks']
    flows = data['flows']
    
    ##Use lines below for K40A_new3 (specific file names were used during this analyis)
    copy = "K40A tiffs and jpgs"
    image_new = inputPath.split('Output')[0] + copy+ inputPath.split('Output')[1]
    image_new = image_new.replace("dapi_cy5","fitc")

    #Rename input file to open fitc file
    image_new = image_new.replace(".npy",".jpg")
    image_new = image_new.replace("_seg","")
    image_new = image_new.replace("overlay","fitc")
    print(image_new)
    
    #Confirm if fitc file exists, read the file and get mean intensity in green channel
    if os.path.isfile(image_new):
        image = skimage.io.imread(image_new)
        uniqueCells = np.unique(masks)
        excludeX = np.arange(image.shape[1] - 4 ,image.shape[1] +1)
        downValues = np.arange(0,5)
        excludeX = np.concatenate((downValues, excludeX))
        excludeY = np.arange(image.shape[0] - 4 ,image.shape[0] +1)
        excludeY = np.concatenate((downValues, excludeY))
        for c in uniqueCells:
            if c != 0:
                cellCoord = np.where(masks==c)
                checkY = np.isin(cellCoord[0],excludeY)
                checkX = np.isin(cellCoord[1],excludeX)
                if np.any(checkY):
                    masks[cellCoord[0], cellCoord[1]] = 0
                    outlines[cellCoord[0], cellCoord[1]] = 0
                elif np.any(checkX):
                    masks[cellCoord[0], cellCoord[1]] = 0
                    outlines[cellCoord[0], cellCoord[1]] = 0
        masks_array = np.asarray(masks)
        prop_dict = regionprops_table(masks_array, intensity_image=image ,properties = properties)
        df = pd.DataFrame(prop_dict)
        #Save mean intensity and other values as csv file
        df.to_csv(inputPath.replace(".npy","_fitc.csv", 1))
        #Save outlines
        outlines = data['outlines']
        outlines_0 = pd.DataFrame(outlines[0])
        outlines_1 = pd.DataFrame(outlines[1])
        outlines =[outlines_0, outlines_1]
        outlines= pd.concat(outlines)
        outlines.to_csv(inputPath.replace(".npy","_outlines.csv", 1))

# %%
# !python -m pip install cellpose[gui]
# Out:
# Requirement already satisfied: cellpose[gui] in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (2.0)
# Requirement already satisfied: numpy>=1.20.0 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (1.26.4)
# Requirement already satisfied: scipy in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (1.13.0)
# Requirement already satisfied: natsort in /home/mzo5929/.local/lib/python3.11/site-packages (from cellpose[gui]) (8.4.0)
# Requirement already satisfied: tifffile in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (2024.2.12)
# Requirement already satisfied: tqdm in /home/mzo5929/.local/lib/python3.11/site-packages (from cellpose[gui]) (4.66.1)
# Requirement already satisfied: numba in /home/mzo5929/.local/lib/python3.11/site-packages (from cellpose[gui]) (0.58.1)
# Requirement already satisfied: torch>=1.6 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (2.2.2)
# Requirement already satisfied: opencv-python-headless in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (3.4.18.65)
# Requirement already satisfied: fastremap in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from cellpose[gui]) (1.14.1)
# Collecting pyqtgraph>=0.11.0rc0 (from cellpose[gui])
#   Downloading pyqtgraph-0.13.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyqt5 (from cellpose[gui])
#   Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting pyqt5.sip (from cellpose[gui])
#   Downloading PyQt5_sip-12.13.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (504 bytes)
# Collecting google-cloud-storage (from cellpose[gui])
#   Downloading google_cloud_storage-2.16.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (4.11.0)
# Requirement already satisfied: sympy in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (1.12)
# Requirement already satisfied: networkx in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (3.3)
# Requirement already satisfied: jinja2 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (3.1.3)
# Requirement already satisfied: fsspec in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from torch>=1.6->cellpose[gui]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->cellpose[gui]) (12.4.127)
# Collecting google-auth<3.0dev,>=2.26.1 (from google-cloud-storage->cellpose[gui])
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-api-core<3.0.0dev,>=2.15.0 (from google-cloud-storage->cellpose[gui])
#   Downloading google_api_core-2.18.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->cellpose[gui])
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.6.0 (from google-cloud-storage->cellpose[gui])
#   Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from google-cloud-storage->cellpose[gui]) (2.31.0)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->cellpose[gui])
#   Downloading google_crc32c-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/mzo5929/.local/lib/python3.11/site-packages (from numba->cellpose[gui]) (0.41.1)
# Collecting PyQt5-Qt5>=5.15.2 (from pyqt5->cellpose[gui])
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl.metadata (535 bytes)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cellpose[gui])
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cellpose[gui])
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cellpose[gui])
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->cellpose[gui])
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->cellpose[gui])
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->cellpose[gui])
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->cellpose[gui]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->cellpose[gui]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->cellpose[gui]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->cellpose[gui]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from jinja2->torch>=1.6->cellpose[gui]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/mzo5929/.conda/envs/cellPose/lib/python3.11/site-packages (from sympy->torch>=1.6->cellpose[gui]) (1.3.0)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage->cellpose[gui])
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Downloading pyqtgraph-0.13.4-py3-none-any.whl (975 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.2/975.2 kB 7.3 MB/s eta 0:00:00:00:010:01
# Downloading google_cloud_storage-2.16.0-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.6/125.6 kB 18.6 MB/s eta 0:00:00
# Downloading PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 58.8 MB/s eta 0:00:00:00:0100:01
# Downloading PyQt5_sip-12.13.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.7/346.7 kB 10.5 MB/s eta 0:00:00
# Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 2.3 MB/s eta 0:00:00ta 0:00:01
# Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 8.2 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.9 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 36.0 MB/s eta 0:00:00:00:0100:01
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.1/229.1 kB 20.1 MB/s eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 1.1 MB/s eta 0:00:00eta 0:00:01
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 7.5 MB/s eta 0:00:00ta 0:00:01
# Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 3.0 MB/s eta 0:00:00ta 0:00:01
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, pyqtgraph, pyqt5.sip, pyasn1, protobuf, google-crc32c, cachetools, rsa, pyqt5, pyasn1-modules, proto-plus, googleapis-common-protos, google-resumable-media, google-auth, google-api-core, google-cloud-core, google-cloud-storage
# Successfully installed PyQt5-Qt5-5.15.2 cachetools-5.3.3 google-api-core-2.18.0 google-auth-2.29.0 google-cloud-core-2.4.1 google-cloud-storage-2.16.0 google-crc32c-1.5.0 google-resumable-media-2.7.0 googleapis-common-protos-1.63.0 proto-plus-1.23.0 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyqt5-5.15.10 pyqt5.sip-12.13.0 pyqtgraph-0.13.4 rsa-4.9
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Out:
# creating new log file
# 2024-04-15 20:08:49,549 [INFO] WRITING LOG OUTPUT TO /home/mzo5929/.cellpose/run.log
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl, xcb.
